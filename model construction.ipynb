# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import gridspec

# %%
data=pd.read_csv("creditcard.csv")

# %%
fraud=data[data['Class']==1]
valid=data[data['Class']==0]

# %%
x=data.drop(['Class'],axis=1)
y=data['Class']
xdata=x.values
ydata=y.values

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(xdata,ydata,test_size=0.2,random_state=128)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
ypred=rfc.predict(xtest)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score

# %%
acc=accuracy_score(ytest,ypred)
precision=precision_score(ytest,ypred)
recallscore=recall_score(ytest,ypred)

# %%
print("The accuracy score is {}".format(acc))
print("The precision score is {}".format(precision))
print("The recall score is {}".format(recallscore))
# Out:
# The accuracy score is 0.9995962220427653
# The precision score is 0.9506172839506173
# The recall score is 0.8020833333333334

# %%
from sklearn.metrics import confusion_matrix
LABELS = ['Normal', 'Fraud']
conf_matrix = confusion_matrix(ytest, ypred)
plt.figure(figsize =(12, 12))
sns.heatmap(conf_matrix, xticklabels = LABELS,
yticklabels = LABELS, annot = True, fmt ="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
